# %% [markdown]
# <a href="https://colab.research.google.com/github/anoopar555/Board_infinity-spotify/blob/main/Annotating_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2
img = cv2.imread('/content/abhishek.semwal@aecom.com--CP_SL4005224_MH3973804991_20200918_1241_60_--26-08-2022.jpg',1)
a = plt.imshow(img)
plt.show()

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('/content/abhishek.semwal@aecom.com--CP_SL4005224_MH3973804991_20200918_1241_60_--26-08-2022.xml')
root = tree.getroot()
root.tag
# Out:
# 'annotation'

# %%
value = root.findall('object/bndbox')
print(value)
# Out:
# [<Element 'bndbox' at 0x7fe014ad7410>]

# %%
for bndbox in root.findall('object/bndbox'):
  x1 = bndbox.find('xmin').text
  x2 = bndbox.find('xmax').text
  y1 = bndbox.find('ymin').text
  y2 = bndbox.find('ymax').text
print(x1,x2,y1,y2)
# Out:
# 10 165 427 463

# %%
from cv2 import imread
imagee = cv2.imread(img)
imageee = cv2.resize(image , (1280,720))
# getting the cordinates in images p1, p2, color of bndbox, thinknessof bndbox, line type respectively.
img_rect= cv2.rectangle(image , (120,600) , (445,424) , (255,0,0) , 2 , cv2.LINE_4)
plt.imshow(img_rect)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-9dd66e4f9b61> in <module>
#       1 from cv2 import imread
# ----> 2 imagee = cv2.imread(img)
#       3 imageee = cv2.resize(image , (1280,720))
#       4 # getting the cordinates in images p1, p2, color of bndbox, thinknessof bndbox, line type respectively.
#       5 img_rect= cv2.rectangle(image , (120,600) , (445,424) , (255,0,0) , 2 , cv2.LINE_4)
#
# TypeError: Can't convert object to 'str' for 'filename'
